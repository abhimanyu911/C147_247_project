# %% [markdown]
# # Baseline model (No skip, no dropout)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_emg_metrics(csv_path: str):
    """
    Reads a CSV metrics file from emg2qwerty logs and generates two plots:
    1) Train and Validation Loss vs. Epoch
    2) Train and Validation CER vs. Epoch

    Args:
        csv_path (str): File path to the CSV metrics log.
    """
    # 1) Load the CSV file
    df = pd.read_csv(csv_path)

    # 2) Convert 'epoch' column to numeric and filter out rows without valid epochs
    df['epoch'] = pd.to_numeric(df['epoch'], errors='coerce')
    df = df[df['epoch'].notnull()]

    # 3) Convert relevant metrics to numeric
    for col in ["train/loss", "train/CER", "val/loss", "val/CER"]:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')

    # 4) Group by epoch and take the last non-null value for each metric
    grouped = df.groupby("epoch").agg({
        "train/loss": "last",
        "train/CER": "last",
        "val/loss": "last",
        "val/CER": "last"
    }).reset_index()

    # 5) Sort by epoch in case rows are out of order
    grouped = grouped.sort_values("epoch")

    # ---------- Plot 1: Train and Validation Loss vs. Epoch ----------
    plt.figure(figsize=(10, 6))
    plt.plot(grouped["epoch"], grouped["train/loss"], marker='o', linestyle='-', label="Train Loss")
    plt.plot(grouped["epoch"], grouped["val/loss"], marker='s', linestyle='--', label="Val Loss")
    plt.xlabel("Epoch", fontsize=12)
    plt.ylabel("Loss", fontsize=12)
    plt.title("Train and Validation Loss vs. Epoch", fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

    # ---------- Plot 2: Train and Validation CER vs. Epoch ----------
    plt.figure(figsize=(10, 6))
    plt.plot(grouped["epoch"], grouped["train/CER"], marker='o', linestyle='-', label="Train CER")
    plt.plot(grouped["epoch"], grouped["val/CER"], marker='s', linestyle='--', label="Val CER")
    plt.xlabel("Epoch", fontsize=12)
    plt.ylabel("CER", fontsize=12)
    plt.title("Train and Validation CER vs. Epoch", fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
csv_path = "logs/2025-03-02/17-39-57/training_logs/version_0/metrics.csv"
plot_emg_metrics(csv_path)

# %% [markdown]
# # Dropout added

# %%
csv_path = "logs/2025-03-02/16-29-02/training_logs/version_0/metrics.csv"
plot_emg_metrics(csv_path)

# %% [markdown]
# # Dropout added, skip added

# %%
csv_path = "logs/2025-03-02/18-54-04/training_logs/version_0/metrics.csv"
plot_emg_metrics(csv_path)

# %% [markdown]
# # Baseline + skip

# %%
csv_path = "logs/2025-03-02/19-44-17/training_logs/version_0/metrics.csv"
plot_emg_metrics(csv_path)

# %%
import subprocess
import re

def extract_metrics(output: str) -> dict:
    """
    Extracts test/loss and test/CER from the output text using regular expressions.
    Assumes that the output contains lines like:
      test/loss: <value>
      test/CER: <value>
    Returns a dictionary with keys "test/loss" and "test/CER".
    """
    metrics = {}
    # Regex patterns to extract the value after test/loss and test/CER (allow decimals)
    loss_pattern = r"(?:['\"]?test/loss['\"]?\s*:\s*)([0-9]+(?:\.[0-9]+)?)"
    cer_pattern  = r"(?:['\"]?test/CER['\"]?\s*:\s*)([0-9]+(?:\.[0-9]+)?)"
    
    loss_match = re.search(loss_pattern, output)
    cer_match  = re.search(cer_pattern, output)
    
    if loss_match:
        try:
            metrics["test/loss"] = float(loss_match.group(1))
        except Exception as e:
            metrics["test/loss"] = "N/A"
    else:
        metrics["test/loss"] = "N/A"
    
    if cer_match:
        try:
            metrics["test/CER"] = float(cer_match.group(1))
        except Exception as e:
            metrics["test/CER"] = "N/A"
    else:
        metrics["test/CER"] = "N/A"
        
    return metrics

def test_and_tabulate_models():
    """
    Runs the emg2qwerty.train script with train=false and appropriate model override and checkpoint,
    then extracts 'test/loss' and 'test/CER' from the output and prints a simple table.
    """
    # Mapping: Model Name -> (checkpoint path, model override)
    model_info = {
        "Baseline (TDSConvCTCModule) (skip present)": ("logs/2025-03-02/17-39-57/checkpoints/epoch=73-step=8880.ckpt", "tds_conv_ctc"),
        "Baseline + dropout - skip connections":          ("logs/2025-03-02/16-29-02/checkpoints/epoch=71-step=8640.ckpt", "tds_conv_ctc_with_dropout_no_skip"),
        "Baseline (skip present) + dropout":   ("logs/2025-03-02/18-54-04/checkpoints/epoch=77-step=9360.ckpt", "tds_conv_ctc_with_dropout_with_skip"),
        #"Baseline + skip":             ("logs/2025-03-02/19-44-17/checkpoints/epoch=72-step=8760.ckpt", "tds_conv_ctc_no_dropout_with_skip"),
    }
    
    results = []
    
    for model_name, (ckpt_path, model_override) in model_info.items():
        print(f"\n--- Testing: {model_name} ---")
        # Build the command.
        # Note: Use 'train=false' (all lowercase) and wrap the checkpoint path in quotes.
        cmd = [
            "python", "-m", "emg2qwerty.train",
            "train=false",
            f'checkpoint="{ckpt_path}"',
            f"model={model_override}"
        ]
        ret = subprocess.run(cmd, capture_output=True, text=True)
        print(ret.stdout)
        if ret.stderr.strip():
            print("Errors/Warnings:\n", ret.stderr)
        
        # Extract metrics using regex (from the entire output)
        metrics = extract_metrics(ret.stdout)
        results.append((model_name, metrics))
    
    # Tabulate the results for test/loss and test/CER
    print("\n===== Final Test Metrics =====")
    columns = ["test/loss", "test/CER"]
    header = f"{'Model':40s}" + "".join([f"{col:>15s}" for col in columns])
    print(header)
    
    for name, metrics in results:
        row = f"{name:40s}"
        for col in columns:
            val = metrics.get(col, "N/A")
            if isinstance(val, float):
                row += f"{val:15.3f}"
            else:
                row += f"{str(val):>15s}"
        print(row)

# Run the function
test_and_tabulate_models()
# Out:
# --- Testing: Baseline (TDSConvCTCModule) (skip present) ---
# [2025-03-03 00:43:04,329][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TDSConvCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   block_channels:
#   - 24
#   - 24
#   - 24
#   - 24
#   kernel_width: 32
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 12
# train: false
# checkpoint: logs/2025-03-02/17-39-57/checkpoints/epoch=73-step=8880.ckpt
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 80
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# [2025-03-03 00:43:04,341][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TDSConvCTCModule', 'in_features': 528, 'mlp_features': [384], 'block_channels': [24, 24, 24, 24], 'kernel_width': 32}
# [2025-03-03 00:43:04,577][__main__][INFO] - Loading module from checkpoint logs/2025-03-02/17-39-57/checkpoints/epoch=73-step=8880.ckpt
# [2025-03-03 00:43:04,718][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
#
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:05,  1.05it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:01<00:02,  1.87it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:01<00:01,  2.56it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.14it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.63it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  4.05it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.53it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.43it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#      Validate metric           DataLoader 0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#          val/CER             19.22906494140625
#
#          val/DER            1.5064244270324707
#
#          val/IER             4.674346446990967
#
#          val/SER            13.048294067382812
#
#         val/loss            0.8273004293441772
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Testing: 0it [00:00, ?it/s]
# Testing:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:04<00:00,  4.03s/it]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:04<00:00,  4.05s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#        Test metric             DataLoader 0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#         test/CER            21.352928161621094
#
#         test/DER            1.7289820909500122
#
#         test/IER             4.81953763961792
#
#         test/SER             14.80440902709961
#
#         test/loss           0.8612683415412903
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# {'val_metrics': [{'val/loss': 0.8273004293441772,
#                   'val/CER': 19.22906494140625,
#                   'val/IER': 4.674346446990967,
#                   'val/DER': 1.5064244270324707,
#                   'val/SER': 13.048294067382812}],
#  'test_metrics': [{'test/loss': 0.8612683415412903,
#                    'test/CER': 21.352928161621094,
#                    'test/IER': 4.81953763961792,
#                    'test/DER': 1.7289820909500122,
#                    'test/SER': 14.80440902709961}],
#  'best_checkpoint': ''}
#
# Errors/Warnings:
#  Global seed set to 1501
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#
# --- Testing: Baseline + dropout - skip connections ---
# [2025-03-03 00:43:54,568][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TDSConvCTCModuleNoSkip
#   in_features: 528
#   mlp_features:
#   - 384
#   block_channels:
#   - 24
#   - 24
#   - 24
#   - 24
#   kernel_width: 32
#   dropout_rate: 0.2
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 12
# train: false
# checkpoint: logs/2025-03-02/16-29-02/checkpoints/epoch=71-step=8640.ckpt
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 80
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# [2025-03-03 00:43:54,575][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TDSConvCTCModuleNoSkip', 'in_features': 528, 'mlp_features': [384], 'block_channels': [24, 24, 24, 24], 'kernel_width': 32, 'dropout_rate': 0.2}
# [2025-03-03 00:43:54,767][__main__][INFO] - Loading module from checkpoint logs/2025-03-02/16-29-02/checkpoints/epoch=71-step=8640.ckpt
# [2025-03-03 00:43:54,897][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
#
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:03,  2.00it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.23it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  4.11it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  4.74it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.29it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.65it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.20it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.10it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#      Validate metric           DataLoader 0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#          val/CER             18.67523193359375
#
#          val/DER             4.497119903564453
#
#          val/IER            2.0159504413604736
#
#          val/SER            12.162161827087402
#
#         val/loss            0.7418657541275024
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Testing: 0it [00:00, ?it/s]
# Testing:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:03<00:00,  3.78s/it]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:03<00:00,  3.80s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#        Test metric             DataLoader 0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#         test/CER            19.364599227905273
#
#         test/DER             2.507024049758911
#
#         test/IER            2.0747785568237305
#
#         test/SER            14.782796859741211
#
#         test/loss           0.6689866781234741
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# {'val_metrics': [{'val/loss': 0.7418657541275024,
#                   'val/CER': 18.67523193359375,
#                   'val/IER': 2.0159504413604736,
#                   'val/DER': 4.497119903564453,
#                   'val/SER': 12.162161827087402}],
#  'test_metrics': [{'test/loss': 0.6689866781234741,
#                    'test/CER': 19.364599227905273,
#                    'test/IER': 2.0747785568237305,
#                    'test/DER': 2.507024049758911,
#                    'test/SER': 14.782796859741211}],
#  'best_checkpoint': ''}
#
# Errors/Warnings:
#  Global seed set to 1501
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#
# --- Testing: Baseline (skip present) + dropout ---
# [2025-03-03 00:44:39,763][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TDSConvCTCModuleWithDropout
#   in_features: 528
#   mlp_features:
#   - 384
#   block_channels:
#   - 24
#   - 24
#   - 24
#   - 24
#   kernel_width: 32
#   dropout_rate: 0.2
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 12
# train: false
# checkpoint: logs/2025-03-02/18-54-04/checkpoints/epoch=77-step=9360.ckpt
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 80
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# [2025-03-03 00:44:39,775][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TDSConvCTCModuleWithDropout', 'in_features': 528, 'mlp_features': [384], 'block_channels': [24, 24, 24, 24], 'kernel_width': 32, 'dropout_rate': 0.2}
# [2025-03-03 00:44:39,941][__main__][INFO] - Loading module from checkpoint logs/2025-03-02/18-54-04/checkpoints/epoch=77-step=9360.ckpt
# [2025-03-03 00:44:40,071][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
#
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:02,  2.08it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.17it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.85it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  4.37it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  4.79it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.09it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.61it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.53it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#      Validate metric           DataLoader 0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#          val/CER            23.172351837158203
#
#          val/DER             8.24102783203125
#
#          val/IER             3.322995185852051
#
#          val/SER            11.608329772949219
#
#         val/loss             0.814515233039856
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Testing: 0it [00:00, ?it/s]
# Testing:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:03<00:00,  3.23s/it]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:03<00:00,  3.26s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#        Test metric             DataLoader 0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#         test/CER             18.06786346435547
#
#         test/DER            1.6641452312469482
#
#         test/IER             3.17700457572937
#
#         test/SER            13.226713180541992
#
#         test/loss            0.634236216545105
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# {'val_metrics': [{'val/loss': 0.814515233039856,
#                   'val/CER': 23.172351837158203,
#                   'val/IER': 3.322995185852051,
#                   'val/DER': 8.24102783203125,
#                   'val/SER': 11.608329772949219}],
#  'test_metrics': [{'test/loss': 0.634236216545105,
#                    'test/CER': 18.06786346435547,
#                    'test/IER': 3.17700457572937,
#                    'test/DER': 1.6641452312469482,
#                    'test/SER': 13.226713180541992}],
#  'best_checkpoint': ''}
#
# Errors/Warnings:
#  Global seed set to 1501
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#
# ===== Final Test Metrics =====
# Model                                         test/loss       test/CER
# Baseline (TDSConvCTCModule) (skip present)          0.861         21.353
# Baseline + dropout - skip connections             0.669         19.365
# Baseline (skip present) + dropout                 0.634         18.068

# %% [markdown]
# # LSTM added

# %% [markdown]
# ## 80 epochs

# %%
csv_path = "logs/2025-03-03/01-03-27/training_logs/version_0/metrics.csv"
plot_emg_metrics(csv_path)

# %% [markdown]
# ## 150 epochs

# %%
csv_path = "logs/2025-03-03/02-05-52/training_logs/version_0/metrics.csv"
plot_emg_metrics(csv_path)

# %% [markdown]
# ## MLP features increased to 480 from 384, dropout increased to 0.3 and epochs increased to 400

# %%
csv_path = "logs/2025-03-04/03-33-57/training_logs/version_0/metrics.csv"
plot_emg_metrics(csv_path)

# %%
import subprocess
import re
ckpt_path = 'logs/2025-03-04/03-33-57/checkpoints/epoch=341-step=41040.ckpt'
model_override = 'tds_bilstm_ctc'
cmd = [
            "python", "-m", "emg2qwerty.train",
            "train=false",
            f'checkpoint="{ckpt_path}"',
            f"model={model_override}"
        ]
ret = subprocess.run(cmd, capture_output=True, text=True)
print(ret.stdout)
# Out:
# [2025-03-04 15:23:45,491][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TDSBiLSTMCTCModuleWithDropout
#   in_features: 528
#   mlp_features:
#   - 480
#   block_channels:
#   - 24
#   - 24
#   - 24
#   - 24
#   kernel_width: 32
#   dropout_rate: 0.3
#   lstm_hidden: 128
#   lstm_layers: 2
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 12
# train: false
# checkpoint: logs/2025-03-04/03-33-57/checkpoints/epoch=341-step=41040.ckpt
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 400
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# [2025-03-04 15:23:45,509][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TDSBiLSTMCTCModuleWithDropout', 'in_features': 528, 'mlp_features': [480], 'block_channels': [24, 24, 24, 24], 'kernel_width': 32, 'dropout_rate': 0.3, 'lstm_hidden': 128, 'lstm_layers': 2}
# [2025-03-04 15:23:45,729][__main__][INFO] - Loading module from checkpoint logs/2025-03-04/03-33-57/checkpoints/epoch=341-step=41040.ckpt
# [2025-03-04 15:23:45,959][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
# Inputs shape: torch.Size([621, 32, 2, 16, 33])
# Targets shape: torch.Size([26, 32])
#
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:01<00:08,  1.48s/it]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:01<00:04,  1.21it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:01<00:02,  1.66it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:01,  2.06it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:02<00:00,  2.39it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:02<00:00,  2.67it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  2.99it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  2.88it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#      Validate metric           DataLoader 0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#          val/CER            13.801506042480469
#
#          val/DER            1.7058041095733643
#
#          val/IER             2.237483501434326
#
#          val/SER             9.858219146728516
#
#         val/loss            0.5699820518493652
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Testing: 0it [00:00, ?it/s]
# Testing:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:05<00:00,  5.71s/it]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:05<00:00,  5.74s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#        Test metric             DataLoader 0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#         test/CER            15.647287368774414
#
#         test/DER            1.2751243114471436
#
#         test/IER            1.8586556911468506
#
#         test/SER            12.513507843017578
#
#         test/loss           0.5920501947402954
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# {'val_metrics': [{'val/loss': 0.5699820518493652,
#                   'val/CER': 13.801506042480469,
#                   'val/IER': 2.237483501434326,
#                   'val/DER': 1.7058041095733643,
#                   'val/SER': 9.858219146728516}],
#  'test_metrics': [{'test/loss': 0.5920501947402954,
#                    'test/CER': 15.647287368774414,
#                    'test/IER': 1.8586556911468506,
#                    'test/DER': 1.2751243114471436,
#                    'test/SER': 12.513507843017578}],
#  'best_checkpoint': ''}
